# %%
import random

# %%
x = 0.5
y = 0.4
z = 0.1
for iteration in range(1, 1000):
    a = random.random()
    b = random.random()
    c = random.random()
    res = (a*x + b*y + c*z)
    print("a: {}, b: {}, c: {}, res: {}".format(a, b, c, res))
    assert(res < 1.0)
# Out:
# a: 0.932564011827, b: 0.188471413793, c: 0.855911308346, res: 0.627261702266
# a: 0.617104945835, b: 0.785680756634, c: 0.329467121555, res: 0.655771487727
# a: 0.223488575305, b: 0.100686759919, c: 0.295305069555, res: 0.181549498576
# a: 0.77028186245, b: 0.58452331665, c: 0.900108862034, res: 0.708961144089
# a: 0.00468088101239, b: 0.671861589121, c: 0.119569685405, res: 0.283042044695
# a: 0.270772979205, b: 0.392175334092, c: 0.445859508781, res: 0.336842574118
# a: 0.497948050997, b: 0.923399537816, c: 0.368639705892, res: 0.655197811214
# a: 0.587263501741, b: 0.00209706886355, c: 0.763457632045, res: 0.37081634162
# a: 0.486602810033, b: 0.692365742783, c: 0.77630329744, res: 0.597878031874
# a: 0.610104268687, b: 0.293675446103, c: 0.23357920073, res: 0.445880232857
# a: 0.315811621454, b: 0.776506315254, c: 0.340736300629, res: 0.502581966891
# a: 0.340320582158, b: 0.179992933542, c: 0.810995672782, res: 0.323257031774
# ...
